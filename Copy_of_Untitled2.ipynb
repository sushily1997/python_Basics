# %% [markdown]
# <a href="https://colab.research.google.com/github/sushily1997/python_Basics/blob/main/Copy_of_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Notbook ++**

# %%
#Python program to swap two variables.
print("Hello")
x = 8
y = 15
#Create a temporary variable and swap the values
temp = x
x = y
y = temp
print(x)
print(y)
# Out:
# Hello
# 15
# 8

# %% [markdown]
# ![Capture2.PNG](data:image/png;base64,...)

# %% [markdown]
# **VS code**

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)
