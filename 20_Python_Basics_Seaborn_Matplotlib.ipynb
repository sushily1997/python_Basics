# %% [markdown]
# <a href="https://colab.research.google.com/github/sushily1997/python_Basics/blob/main/20_Python_Basics_Seaborn_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seaborn
#
# Seaborn is a library mostly used for statistical plotting in Python. It is built on top of Matplotlib and provides beautiful default styles and color palettes to make statistical plots more attractive.
#
#
# We will be plotting a simple line plot using the iris dataset. Iris dataset contains five columns such as Petal Length, Petal Width, Sepal Length, Sepal Width and Species Type. Iris is a flowering plant, the researchers have measured various features of the different iris flowers and recorded them digitally.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# importing packages
import seaborn as sb

# loading dataset
data = sb.load_dataset("iris")

data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
# draw lineplot
sb.lineplot(x="sepal_length", y="sepal_width", data=data)

# %%
# Example 2: Setting the xlim and ylim
# importing packages
import seaborn as sb
import matplotlib.pyplot as plt

# loading dataset
data = sb.load_dataset("iris")

# draw lineplot
sb.lineplot(x="sepal_length", y="sepal_width", data=data)

# setting the x limit of the plot
plt.xlim(5)

plt.show()

# %%
# draw lineplot
sb.lineplot(x="petal_length", y="petal_width", data=data)

# %%
# Example 2: Setting the xlim and ylim
# importing packages
import seaborn as sb
import matplotlib.pyplot as plt

# loading dataset
data = sb.load_dataset("iris")

# draw lineplot
sb.lineplot(x="petal_length", y="petal_width", data=data)

# setting the x limit of the plot
plt.xlim(3)

plt.show()

# %% [markdown]
# # Customizing Seaborn Plots
# Seaborn comes with some customized themes and a high-level interface for customizing the looks of the graphs. Consider the above example where the default of the Seaborn is used. It still looks nice and pretty but we can customize the graph according to our own needs. So let’s see the styling of plots in detail.
#
#
#
# Changing Figure Aesthetic
# set_style() method is used to set the aesthetic of the plot. It means it affects things like the color of the axes, whether the grid is active or not, or other aesthetic elements.
#
# There are five themes available in Seaborn.
#
#
#
# darkgrid
#
# whitegrid
#
# dark
#
# white
#
# ticks
#
# Syntax:
#
#
#
# set_style(style=None, rc=None)

# %%
# Example: Using the dark theme

# importing packages
import seaborn as sb
import matplotlib.pyplot as plt

# loading dataset
data = sb.load_dataset("iris")
sb.set_style("dark")

# draw lineplot
sb.lineplot(x="sepal_length", y="sepal_width", data=data)

# changing the theme to dark
plt.show()

# %%
# importing packages
import seaborn as sb
import matplotlib.pyplot as plt

# loading dataset
data = sb.load_dataset("iris")
sb.set_style("dark")

# draw lineplot
sb.lineplot(x="petal_length", y="petal_width", data=data)

# changing the theme to dark
plt.show()

# %% [markdown]
# # Changing the figure Size
# The figure size can be changed using the figure() method of Matplotlib. figure() method creates a new figure of the specified size passed in the figsize parameter.

# %%
# importing packages
import seaborn as sb
import matplotlib.pyplot as plt

# loading dataset
data = sb.load_dataset("iris")

# changing the figure size
plt.figure(figsize = (5, 4))

# draw lineplot
sb.lineplot(x="sepal_length", y="sepal_width", data=data)

# Removing the spines
"""Spines are the lines noting the data boundaries and connecting the axis tick marks. It can be removed using the despine() method."""
sb.despine()

plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")

# changing the figure size
plt.figure(figsize = (9, 6))

# draw lineplot
sb.lineplot(x="sepal_length", y="sepal_width", data=data)

# Removing the spines
"""Spines are the lines noting the data boundaries and connecting the axis tick marks. It can be removed using the despine() method."""
sb.despine()

plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")

# changing the figure size
plt.figure(figsize = (5, 4))

# draw lineplot
sb.lineplot(x="petal_length", y="petal_width", data=data)

# Removing the spines
"""Spines are the lines noting the data boundaries and connecting the axis tick marks. It can be removed using the despine() method."""
sb.despine()

plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")

# changing the figure size
plt.figure(figsize = (9, 6))

# draw lineplot
sb.lineplot(x="petal_length", y="petal_width", data=data)

# Removing the spines
"""Spines are the lines noting the data boundaries and connecting the axis tick marks. It can be removed using the despine() method."""
sb.despine()

plt.show()

# %% [markdown]
# # Multiple plots with Seaborn
# Multiple plots in Seaborn can also be created using the Matplotlib as well as Seaborn also provides some functions for the same.
#
#
#
# Using Matplotlib
# Matplotlib provides various functions for plotting subplots. Some of them are add_axes(), subplot(), and subplot2grid(). Let’s see an example of each function for better understanding.
#
#
#
# Example 1: Using add_axes() method

# %%
# importing packages
import seaborn as sb
import matplotlib.pyplot as plt


# loading dataset
data = sb.load_dataset("iris")
sb.set_style("white")


def graph():
	sb.lineplot(x="sepal_length", y="sepal_width", data=data)

# Creating a new figure with width = 15 inches
# and height =15 inches
fig = plt.figure(figsize =(15, 15))

# Creating first axes for the figure
# The add_axes() method figure module of matplotlib library is used to add an axes to the figure.
"""The syntax is: add_axes(rect), where rect is a list [x0, y0, width, height] denoting the lower left point of the new axes in figure coodinates (x0,y0) 
and its width and height. So the axes is positionned in absolute coordinates on the canvas. """
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# plotting the graph
graph()

# Creating second axes for the figure
ax2 = fig.add_axes([0.5, 0.6, 0.2, 0.2])

# plotting the graph
graph()

plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")
sb.set_style("white")


def graph():
  sb.lineplot(x="petal_length", y="petal_width", data=data)

# Creating a new figure with width = 15 inches
# and height =15 inches
fig = plt.figure(figsize =(15, 15))

ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# plotting the graph
graph()

# Creating second axes for the figure
ax2 = fig.add_axes([0.6, 0.3, 0.2, 0.2])

# plotting the graph
graph()

plt.show()

# %%
# importing packages
import seaborn as sb
import matplotlib.pyplot as plt


# loading dataset
data = sb.load_dataset("iris")
sb.set_style("darkgrid")


def graph():
	sb.lineplot(x="sepal_length", y="sepal_width", data=data)

# Creating a new figure with width = 15 inches
# and height =15 inches
fig = plt.figure(figsize =(15, 15))

# Creating first axes for the figure
# The add_axes() method figure module of matplotlib library is used to add an axes to the figure.
"""The syntax is: add_axes(rect), where rect is a list [x0, y0, width, height] denoting the lower left point of the new axes in figure coodinates (x0,y0) 
and its width and height. So the axes is positionned in absolute coordinates on the canvas. """
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# plotting the graph
graph()

# Creating second axes for the figure
ax2 = fig.add_axes([0.5, 0.6, 0.2, 0.2])

# plotting the graph
graph()

plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")
sb.set_style("darkgrid")


def graph():
  sb.lineplot(x="petal_length", y="petal_width", data=data)

# Creating a new figure with width = 15 inches
# and height =15 inches
fig = plt.figure(figsize =(15, 15))

ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# plotting the graph
graph()

# Creating second axes for the figure
ax2 = fig.add_axes([0.6, 0.3, 0.2, 0.2])

# plotting the graph
graph()

plt.show()

# %% [markdown]
# ### Example 2: Using subplot() method
#
# subplot() function adds subplot to a current figure at the specified grid position.  It is similar to the subplots() function however unlike subplots() it adds one subplot at a time. So to create multiple plots you will need several lines of code with the subplot() function. Another drawback of the subplot function is that it deletes the preexisting plot on your figure.
#
# Syntax:
#
# subplot(nrows, ncols, index, **kwargs)
#
# subplot(pos, **kwargs)
#
# subplot(ax)
#
# Parameters :
#
# args:  Either a 3-digit integer or three separate integers describing the position of the subplot.
#
# pos is a three-digit integer where the first, second, and third integer are nrows,ncols, index.
#
# projection : [{None, ’aitoﬀ’, ’hammer’, ’lambert’, ’mollweide’, ’polar’, ’rectilinear’, str}, optional]. The projection-type of the subplot (Axes). The default None results in a ’rectilinear’ projection.
#
# label : [str] A label for the returned axes.
#
# **kwargs: This method also takes the keyword arguments for the returned axes base class;
# except for the ﬁgure argument, for e.g facecolor.
#
# Returns :  An axes.SubplotBase subclass of Axes or a subclass of Axes. The returned axes base class depends on the projection used.

# %%
# importing packages
import seaborn as sb
import matplotlib.pyplot as plt


# loading dataset
data = sb.load_dataset("iris")

def graph():
	sb.lineplot(x="sepal_length", y="sepal_width", data=data)

#fig size
plt.figure(figsize=(10,5))
# Adding the subplot at the specified
# grid position
# args:  Either a 3-digit integer or three separate integers describing the position of the subplot.

plt.subplot(121)
graph()


# Adding the subplot at the specified
# grid position
plt.subplot(122)
graph()

plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")

def graph():
	sb.lineplot(x="petal_length", y="petal_width", data=data)

#fig size
plt.figure(figsize=(10,5))
# Adding the subplot at the specified
# grid position
# args:  Either a 3-digit integer or three separate integers describing the position of the subplot.

plt.subplot(121)
graph()


# Adding the subplot at the specified
# grid position
plt.subplot(122)
graph()

plt.show()

# %% [markdown]
# # Multiple plot using seaborn
#
# ## Method 1: Using FacetGrid() method
#
#
#
# FacetGrid class helps in visualizing distribution of one variable as well as the relationship between multiple variables separately within subsets of your dataset using multiple panels.
#
# A FacetGrid can be drawn with up to three dimensions ? row, col, and hue. The first two have obvious correspondence with the resulting array of axes; think of the hue variable as a third dimension along a depth axis, where different levels are plotted with different colors.
#
# FacetGrid object takes a dataframe as input and the names of the variables that will form the row, column, or hue dimensions of the grid. The variables should be categorical and the data at each level of the variable will be used for a facet along that axis.

# %%
# importing packages
import seaborn as sb
import matplotlib.pyplot as plt

# loading dataset
data = sb.load_dataset("iris")

plot = sb.FacetGrid(data, col="species")
plot.map(plt.plot, "sepal_width")

plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")

plot = sb.FacetGrid(data, col="species")
plot.map(plt.plot, "sepal_length")

plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")

plot = sb.FacetGrid(data, col="species")
plot.map(plt.plot, "petal_width")

plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")

plot = sb.FacetGrid(data, col="species")
plot.map(plt.plot, "petal_length")

plt.show()

# %% [markdown]
# # **Creating Different Types of Plots**
#
#
# ## Relational Plots
# Relational plots are used for visualizing the statistical relationship between the data points. Visualization is necessary because it allows the human to see trends and patterns in the data. The process of understanding how the variables in the dataset relate each other and their relationships are termed as Statistical analysis. Refer to the below articles for detailed information.

# %% [markdown]
# # Relplot()
# This function provides us the access to some other different axes-level functions which shows the relationships between two variables with semantic mappings of subsets. It is plotted using the relplot() method.

# %%
# loading dataset
data = sb.load_dataset("iris")

# creating the relplot
sb.relplot(x='sepal_width', y='species', data=data)

plt.show()

# %%
data = sb.load_dataset("iris")

# creating the relplot
sb.relplot(x='sepal_length', y='species', data=data)

plt.show()

# %%
data = sb.load_dataset("iris")

# creating the relplot
sb.relplot(x='petal_width', y='species', data=data)

plt.show()

# %%
data = sb.load_dataset("iris")

# creating the relplot
sb.relplot(x='petal_length', y='species', data=data)

plt.show()

# %% [markdown]
# # Scatter Plot
# The scatter plot is a mainstay of statistical visualization. It depicts the joint distribution of two variables using a cloud of points, where each point represents an observation in the dataset. This depiction allows the eye to infer a substantial amount of information about whether there is any meaningful relationship between them. It is plotted using the scatterplot() method.

# %%
sb.scatterplot(x='sepal_length', y='sepal_width', data=data)
plt.show()

# %%
sb.scatterplot(x='petal_length', y='petal_width', data=data)
plt.show()

# %% [markdown]
# # Line Plot
#
#
# For certain datasets, you may want to consider changes as a function of time in one variable, or as a similarly continuous variable. In this case, drawing a line-plot is a better option. It is plotted using the lineplot() method.

# %%
# importing packages
import seaborn as sb
import matplotlib.pyplot as plt

# loading dataset
data = sb.load_dataset("iris")

sb.lineplot(x='sepal_width', y='species', data=data)
plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")

sb.lineplot(x='sepal_length', y='species', data=data)
plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")

sb.lineplot(x='petal_width', y='species', data=data)
plt.show()

# %%
# loading dataset
data = sb.load_dataset("iris")

sb.lineplot(x='petal_length', y='species', data=data)
plt.show()

# %% [markdown]
# # Seaborn | Categorical Plots
#
# Plots are basically used for visualizing the relationship between variables. Those variables can be either be completely numerical or a category like a group, class or division. This article deals with categorical variables and how they can be visualized using the Seaborn library provided by Python.
#
# Seaborn besides being a statistical plotting library also provides some default datasets. We will be using one such default dataset called ‘tips’. The ‘tips’ dataset contains information about people who probably had food at a restaurant and whether or not they left a tip for the waiters, their gender, whether they smoke and so on.
# Let us have a look at the tips dataset.

# %%
# import the seaborn library
import seaborn as sb

# import done to avoid warnings
from warnings import filterwarnings

# reading the dataset
df = sb.load_dataset('tips')

# first five entries if the dataset
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# Now lets proceed onto the plots so that we can how we can visualize these categorical variables.

# %% [markdown]
# ## Barplot
# A barplot is basically used to aggregate the categorical data according to some methods and by default its the mean. It can also be understood as a visualization of the group by action. To use this plot we choose a categorical column for the x axis and a numerical column for the y axis and we see that it creates a plot taking a mean per categorical column.

# %%
# set the background style of the plot
sb.set_style('dark')

# plot the graph using the default estimator mean
sb.barplot(x ='sex', y ='total_bill', data = df, palette ='plasma')

# %%
sb.set_style('dark')

# plot the graph using the default estimator mean
sb.barplot(x ='sex', y ='tip', data = df, palette ='plasma')

# %%
sb.set_style('dark')
# plot the graph using the default estimator mean
sb.barplot(x ='total_bill', y ='tip', data = df,palette='plasma')
#set custom color pallete

# %%
# or
import numpy as np

# change the estimator from mean to standard deviation
sb.barplot(x ='sex', y ='total_bill', data = df,
			palette ='plasma', estimator = np.std)

# %%
# change the estimator from mean to standard deviation
sb.barplot(x ='total_bill', y ='tip', data = df,
			palette ='plasma', estimator = np.std)

# %% [markdown]
# Explanation/Analysis:
#
# Looking at the plot we can say that the average total_bill for the male is more as compared to the female.
#
# palette is used to set the color of the plot
# estimator is used as a statistical function for estimation within each categorical bin.

# %% [markdown]
# ## Countplot
# A countplot basically counts the categories and returns a count of their occurrences. It is one of the most simple plots provided by the seaborn library.
#
# Explanation/Analysis
#
# Looking at the plot we can say that the number of males is more than the number of females in the dataset. As it only returns the count based off a categorical column, we need to specify only the x parameter.

# %%
sb.set_style('ticks')
sb.countplot(x ='sex', data = df)

# %%
# Quality Check
df.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sb.set_style('ticks')
sb.countplot(x ='tip', data = df)

# %%
df.tip.value_counts()
# Out:
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: tip, Length: 123, dtype: int64

# %% [markdown]
# # Boxplot
# A boxplot is sometimes known as the box and whisker plot.It shows the distribution of the quantitative data that represents the comparisons between variables. boxplot shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution i.e. the dots indicating the presence of outliers.

# %%
sb.boxplot(x ='day', y ='total_bill', data = df, hue ='smoker')

# %%
df.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sb.boxplot(x ='sex', y ='total_bill', data = df, hue ='day')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Find outliers using the interquartile range**

# %%
#set(-4,-3,-2,-1,0,1,2,3,4)
#Find the IQR,Q1(25th percentile) and Q3(75th percentile)
#(-4,-3,-2,-1)0(1,2,3,4)
Q1 = -3.5
Q3 = 2.5

# %%
#Interquartile range turn out to be Q1 and Q3
2.5-(-3.5)
# Out:
# 6.0

# %%
#calculate 1.5*IQR
#Lower limit = Q1-1.5*IQR
-3.5-1.5*6.0
# Out:
# -12.5

# %%
#Add the upper limited is calculated as
#Upper limit=Q3+1.5*IQR
2.5+1.5*6.0
# Out:
# 11.5

# %% [markdown]
# **Example 2**

# %%
#Interquartile range caculator
##STEP 1##
#Data set: 3,15,17,19,22,24,27,30,32,45
#Find the IQR,Q1(25th percentile) and Q3(75th percentile)
#IQR = 22
#Q1 = 17
#Q3 = 30

# %%
#25th percentile : 14
#75th percentile : 30
#Interquartile Range : 22

# %%
##Step 2##
#Multiply the IQR found in step 1 by 1.5:
#IQR*1.5
22*1.5
# Out:
# 33.0

# %%
##Step 3##
#Add the amount found in step 2 to Q3 from step 1:
33+30
# Out:
# 63

# %%
#Subtract the amount found in step 2 from Q1 from step 1
14-30
# Out:
# -16
