# %% [markdown]
# <a href="https://colab.research.google.com/github/sushily1997/python_Basics/blob/main/17_Python_Basics_Pandas_DateTime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working with date and time using Pandas

# %% [markdown]
# ![Web capture_9-5-2022_102453_datagy.io.jpeg](data:image/jpeg;base64,...)

# %%
# Code #1: Create a dates dataframe 

import pandas as pd

# Create dates dataframe with frequency
data = pd.date_range('1/1/2011', periods = 10, freq ='H')

data
# Out:
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
import datetime

a = datetime.datetime.today()
numdays = 10
dateList = []
for x in range (0, numdays):
    dateList.append(a - datetime.timedelta(days = x))

# %%
print(dateList)
# Out:
# [datetime.datetime(2022, 5, 9, 11, 20, 14, 578144), datetime.datetime(2022, 5, 8, 11, 20, 14, 578144), datetime.datetime(2022, 5, 7, 11, 20, 14, 578144), datetime.datetime(2022, 5, 6, 11, 20, 14, 578144), datetime.datetime(2022, 5, 5, 11, 20, 14, 578144), datetime.datetime(2022, 5, 4, 11, 20, 14, 578144), datetime.datetime(2022, 5, 3, 11, 20, 14, 578144), datetime.datetime(2022, 5, 2, 11, 20, 14, 578144), datetime.datetime(2022, 5, 1, 11, 20, 14, 578144), datetime.datetime(2022, 4, 30, 11, 20, 14, 578144)]

# %% [markdown]
# Datetime features can be divided into two categories. The first one time moments in a period and second the time passed since a particular period. These features can be very useful to understand the patterns in the data.
#
# Divide a given date into features –
#
# pandas.Series.dt.year returns the year of the date time.
#
# pandas.Series.dt.month returns the month of the date time.
#
# pandas.Series.dt.day returns the day of the date time.
#
# pandas.Series.dt.hour returns the hour of the date time.
#
# pandas.Series.dt.minute returns the minute of the date time.

# %%
# Create date and time with dataframe
rng = pd.DataFrame()
rng['date'] = pd.date_range('03/06/2022', periods = 72, freq ='H')

# Print the dates in dd-mm-yy format
rng[:8]

# Create features for year, month, day, hour, and minute
rng['year'] = rng['date'].dt.year
rng['month'] = rng['date'].dt.month
rng['day'] = rng['date'].dt.day
rng['hour'] = rng['date'].dt.hour
rng['minute'] = rng['date'].dt.minute

# Print the dates divided into features
rng.head(5)
# Out:
#                  date  year  month  day  hour  minute
# 0 2022-03-06 00:00:00  2022      3    6     0       0
# 1 2022-03-06 01:00:00  2022      3    6     1       0
# 2 2022-03-06 02:00:00  2022      3    6     2       0
# 3 2022-03-06 03:00:00  2022      3    6     3       0
# 4 2022-03-06 04:00:00  2022      3    6     4       0

# %%
# Create date and time with dataframe
rng = pd.DataFrame()
rng['date'] = pd.date_range('2022/03/05', periods = 52, freq ='d')

# Print the dates in dd-mm-yy format
rng[:8]

# Create features for year, month, day, hour, and minute
rng['year'] = rng['date'].dt.year
rng['month'] = rng['date'].dt.month
rng['day'] = rng['date'].dt.day
rng['hour'] = rng['date'].dt.hour
rng['minute'] = rng['date'].dt.minute

# Print the dates divided into features
rng.head(5)
# Out:
#         date  year  month  day  hour  minute
# 0 2022-03-05  2022      3    5     0       0
# 1 2022-03-06  2022      3    6     0       0
# 2 2022-03-07  2022      3    7     0       0
# 3 2022-03-08  2022      3    8     0       0
# 4 2022-03-09  2022      3    9     0       0

# %%
"""Code #4: To get the present time"""
from datetime import date

today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2022-05-09

# %%
#Example 2: Current date in different formats

from datetime import date

today = date.today()

# dd/mm/YY
d1 = today.strftime("%d/%m/%Y")
print("d1 =", d1)

# Textual month, day and year	
d2 = today.strftime("%B %d, %Y")
print("d2 =", d2)

# mm/dd/y
d3 = today.strftime("%m/%d/%y")
print("d3 =", d3)

# Month abbreviation, day and year	
d4 = today.strftime("%b-%d-%Y")
print("d4 =", d4)
# Out:
# d1 = 09/05/2022
# d2 = May 09, 2022
# d3 = 05/09/22
# d4 = May-09-2022

# %% [markdown]
# **Date Format Types**
#
# Month abbreviations consist of the first three characters of the month’s name. Months with four-character names, such as June, are not abbreviated.

# %% [markdown]
# ![Web capture_9-5-2022_191441_docs.oracle.com.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Timedelta
# So far, we have seen how to create a DateTime object and how to format it. But sometimes, you might have to find the duration between two dates, which can be another very useful feature that you can derive from a dataset. This duration is, however, returned as a timedelta object.

# %%
# timedelta : duration between dates
from datetime import datetime, time

d1 = datetime(2022,4,23,11,13,10)
d2 = datetime(2023,4,23,12,13,10)
print(d1)
print(d2)
duration = d2-d1
print(type(duration))
duration
# Out:
# 2022-04-23 11:13:10
# 2023-04-23 12:13:10
# <class 'datetime.timedelta'>
# datetime.timedelta(days=365, seconds=3600)

# %% [markdown]
# # Datetime and Pandas Dataframe

# %%
import pandas as pd

url = 'http://bit.ly/uforeports'

# read csv file
df = pd.read_csv(url)		
df.head(10)
# Out:
#                    City Colors Reported Shape Reported State              Time
# 0                Ithaca             NaN       TRIANGLE    NY    6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ   6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO   2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS    6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY   4/18/1933 19:00
# 5           Valley City             NaN           DISK    ND   9/15/1934 15:30
# 6           Crater Lake             NaN         CIRCLE    CA    6/15/1935 0:00
# 7                  Alma             NaN           DISK    MI    7/15/1936 0:00
# 8               Eklutna             NaN          CIGAR    AK  10/15/1936 17:00
# 9               Hubbard             NaN       CYLINDER    OR    6/15/1937 0:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18216 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %%
# Convert the Time column to datetime format
df['Time'] = pd.to_datetime(df.Time)

df.head(7)
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
# 5           Valley City             NaN           DISK    ND
# 6           Crater Lake             NaN         CIRCLE    CA
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00
# 5 1934-09-15 15:30:00
# 6 1935-06-15 00:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18216 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 712.7+ KB

# %%
import pandas as pd
import numpy as np
t1 = pd.to_datetime('2022-05-08 19:03:04')
t2 = pd.to_datetime('2022-05-09 11:00:48')
(t2-t1).seconds/(60*60)
# Out:
# 15.962222222222222

# %%
dates = pd.date_range('2022-05-09 02:34:54','2022-06-14 00:00:00',periods=22).values
np.random.shuffle(dates)
df = pd.DataFrame(dates.reshape(11,2),columns=['t1','t2'])
df
# Out:
#                               t1                            t2
# 0  2022-06-08 20:56:24.857142857 2022-05-12 12:37:17.428571428
# 1  2022-06-10 13:57:36.571428571 2022-05-26 04:46:51.142857142
# 2  2022-06-05 10:54:01.428571428 2022-06-02 00:51:38.000000000
# 3  2022-05-19 08:42:04.285714285 2022-06-07 03:55:13.142857143
# 4  2022-06-14 00:00:00.000000000 2022-05-14 05:38:29.142857142
# 5  2022-05-15 22:39:40.857142857 2022-05-27 21:48:02.857142857
# 6  2022-05-29 14:49:14.571428571 2022-05-31 07:50:26.285714285
# 7  2022-05-17 15:40:52.571428571 2022-05-21 01:43:16.000000000
# 8  2022-06-12 06:58:48.285714285 2022-05-10 19:36:05.714285714
# 9  2022-05-09 02:34:54.000000000 2022-05-22 18:44:27.714285714
# 10 2022-05-24 11:45:39.428571428 2022-06-03 17:52:49.714285714

# %%
(df['t1']-df['t2']).apply(lambda x: x.seconds/(60*60))
# Out:
# 0      8.318611
# 1      9.179167
# 2     10.039722
# 3      4.780833
# 4     18.358333
# 5      0.860556
# 6      6.980000
# 7     13.960000
# 8     11.378333
# 9      7.840556
# 10    17.880278
# dtype: float64

# %%
(df['t1']-df['t2'])/np.timedelta64(1,'h')
# Out:
# 0     656.318730
# 1     369.179286
# 2      82.039841
# 3    -451.219127
# 4     738.358571
# 5    -287.139444
# 6     -41.019921
# 7     -82.039841
# 8     779.378492
# 9    -328.159365
# 10   -246.119524
# dtype: float64

# %% [markdown]
# # Day first format
# By default, to_datetime() will parse string with month first (MM/DD, MM DD, or MM-DD) format, and this arrangement is relatively unique in the United State.
#
# In most of the rest of the world, the day is written first (DD/MM, DD MM, or DD-MM). If you would like Pandas to consider day first instead of month, you can set the argument dayfirst to True.

# %%
df = pd.DataFrame({'date': ['03/10/2022', '03/11/2022', '03/12/2022'], 'value': [2, 3, 4]})
df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df
# Out:
#         date  value
# 0 2022-10-03      2
# 1 2022-11-03      3
# 2 2022-12-03      4

# %%
jan = pd.date_range(start='2022-01-01', end='2022-01-31')

data = {"registered": [5, 4, 3, 4, 3, 5, 1, 6, 1, 9, 5, 3, 7, 2, 8, 4, 4, 6, 4, 3, 2, 5, 3, 4, 2, 6, 8, 5, 3, 4, 5]}
df = pd.DataFrame(data, index=jan)

print(df.first('8D'))
# Out:
#             registered
# 2022-01-01           5
# 2022-01-02           4
# 2022-01-03           3
# 2022-01-04           4
# 2022-01-05           3
# 2022-01-06           5
# 2022-01-07           1
# 2022-01-08           6

# %% [markdown]
# # Custome format
# By default, strings are parsed using the Pandas built-in parser from dateutil.parser.parse. Sometimes, your strings might be in a custom format, for example, YYYY-DD-MM HH:MM:SS. Pandas to_datetime() has an argument called format that allows you to pass a custom format:

# %%
df = pd.DataFrame({'date': ['2022-6-10 20:30:0', 
                            '2023-7-1 19:45:30', 
                            '2024-10-12 4:5:1'],
                   'value': [2, 3, 4]})
print(df)
print("*****************************")
df['date'] = pd.to_datetime(df['date'], format="%Y-%d-%m %H:%M:%S")
df
# Out:
#                 date  value
# 0  2022-6-10 20:30:0      2
# 1  2023-7-1 19:45:30      3
# 2   2024-10-12 4:5:1      4
# *****************************
#                  date  value
# 0 2022-10-06 20:30:00      2
# 1 2023-01-07 19:45:30      3
# 2 2024-12-10 04:05:01      4

# %% [markdown]
# ## Pandas Timestamp.replace
#
# Pandas Timestamp.replace() function is used to replace the member values of the given Timestamp. The function implements datetime.replace, and it also handles nanoseconds.

# %%
# Example #1: Use Timestamp.replace() function to replace the year value in the given Timestamp.

# importing pandas as pd
import pandas as pd

# Create the Timestamp object
ts = pd.Timestamp(year = 2022, month = 11, day = 12,
				hour = 10, second = 49, tz = 'US/Central')

# Print the Timestamp object
print(ts)
# Out:
# 2022-11-12 10:00:49-06:00

# %%
# Now we will use the Timestamp.replace() function to replace the current year in the object with 2019.

# replace year
ts.replace(year = 2022)
# Out:
# Timestamp('2022-11-12 10:00:49-0600', tz='US/Central')

# %%
#Example #2: Use Timestamp.replace() function to replace the year, month and hour value in the given Timestamp.

# importing pandas as pd
import pandas as pd

# Create the Timestamp object
ts = pd.Timestamp(year = 2022, month = 5, day = 12,
				hour = 4, second = 49, tz = 'Europe/Berlin')

# Print the Timestamp object
print(ts)
# Out:
# 2022-05-12 04:00:49+02:00

# %%
from pytz import timezone 
from datetime import datetime

ind_time = datetime.now(timezone("Asia/Kolkata")).strftime('%Y-%m-%d %H:%M:%S.%f')
print(ind_time)
# Out:
# 2022-05-09 22:09:27.455078

# %%
# Now we will use the Timestamp.replace() function to replace the current year, month and hour value in the object.

# replace year, month and hour value
ts.replace(year = 2022, month = 5, hour = 1)
# Out:
# Timestamp('2022-05-12 01:00:49+0200', tz='Europe/Berlin')

# %%
# importing pandas as pd
import pandas as pd
  
# Creating the date series
date_sr = pd.Series(pd.date_range(
    '2022-05-09', periods=3, freq='M', tz='Asia/Calcutta'))
  
# Creating the index
ind = ['Day 1', 'Day 2', 'Day 3']
  
# set the index
date_sr.index = ind
change_format = date_sr.dt.strftime('%d,%m,%Y')
  
# Print the formated date
print(change_format)
# Out:
# Day 1    31,05,2022
# Day 2    30,06,2022
# Day 3    31,07,2022
# dtype: object

# %% [markdown]
# # pandas.date_range() method
#
# pandas.date_range() is one of the general functions in Pandas which is used to return a fixed frequency DatetimeIndex.

# %%
# importing pandas as pd
import pandas as pd

per1 = pd.date_range(start ='01-04-2022',
		end ='01-05-2022', freq ='5H')

for val in per1:
	print(val)
# Out:
# 2022-01-04 00:00:00
# 2022-01-04 05:00:00
# 2022-01-04 10:00:00
# 2022-01-04 15:00:00
# 2022-01-04 20:00:00

# %%
pd.date_range(start='09/05/2022', end='10/06/2022', periods=8)
# Out:
# DatetimeIndex([          '2022-09-05 00:00:00',
#                '2022-09-09 10:17:08.571428571',
#                '2022-09-13 20:34:17.142857142',
#                '2022-09-18 06:51:25.714285714',
#                '2022-09-22 17:08:34.285714285',
#                '2022-09-27 03:25:42.857142857',
#                '2022-10-01 13:42:51.428571428',
#                          '2022-10-06 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
# importing pandas as pd
import pandas as pd

dRan1 = pd.date_range(start ='01-01-2022',
		end ='08-01-2022', freq ='M')

dRan2 = pd.date_range(start ='1-1-2022',
		end ='11-01-2022', freq ='3M')

print(dRan1, '\n\n', dRan2)
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31'],
#               dtype='datetime64[ns]', freq='M')
#
#  DatetimeIndex(['2022-01-31', '2022-04-30', '2022-07-31', '2022-10-31'], dtype='datetime64[ns]', freq='3M')

# %% [markdown]
# # Usecase

# %%
url='https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv'
data = pd.read_csv(url,sep=",")

# %%
data.head(6)
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN
# 5  2006-01-06     1403.427   NaN    NaN         NaN

# %% [markdown]
# ## Converting data to correct format
# when working with time series, it becomes much easier if we have the Datecolumn represented as a Timestamp. Timestamp is the main pandas data structures for working with dates and times. The pandas function to_datetime() can help us convert a string to a proper date/time format.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   object
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 171.3+ KB

# %%
# to explicitly convert the date column to type DATETIME
data['Date'] = pd.to_datetime(data['Date'])
data.dtypes
# Out:
# Date           datetime64[ns]
# Consumption           float64
# Wind                  float64
# Solar                 float64
# Wind+Solar            float64
# dtype: object

# %% [markdown]
# We will now go ahead and set this column as the index for the dataframe using the set_index() call.

# %%
data = data.set_index('Date')
data
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
data.index # checking index of data
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %% [markdown]
# An interesting thing to note here is thatfreq = None. What this means is that it is not known if data is collected by the hour, by day, my minute, etc. However, just by eyeballing the indices, we can see that it looks like the data was collected by the day. It would be nice to explicitly put this info into the data frame as well and we will be seeing how to do this shortly! But first a quick detour…
#
# ### What if I want to set Date and Time, both as the index?
# You will come across datasets where the Date and Time were recorded as separate columns at the time of data collection. A simple yet neat trick to set them as data index is:
#
# Concatenate the two columns but with a space between them.
#
# The space is important!!
#
# Convert this concatenated column to a Timestamp using to_datetime().
#
# Set this concatenated column as the index using set_index().

# %%
df['Datetime'] = pd.to_datetime(df['date'] + ' ' + df['time'])
df = df.set_index('Datetime')

# %% [markdown]
# ## Missing value imputations
# As we mentioned previously, quick glance at the data suggests it was collected at an interval of 24 hours (or a day). However, the data reflects freq = None. We can correct it as follows:

# %%
data_freq = data.asfreq('D')
data_freq
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
data_freq = data.asfreq('Y')
data_freq
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-12-31   1144.39800      NaN     NaN         NaN
# 2007-12-31   1145.58200      NaN     NaN         NaN
# 2008-12-31   1117.61700      NaN     NaN         NaN
# 2009-12-31   1106.46700      NaN     NaN         NaN
# 2010-12-31   1199.81200  117.325     NaN         NaN
# 2011-12-31   1077.62500   83.185     NaN         NaN
# 2012-12-31    969.81000  446.492  25.097     471.589
# 2013-12-31   1068.42900  174.670  43.219     217.889
# 2014-12-31   1183.51000  145.511   3.721     149.232
# 2015-12-31   1158.10300  358.330  20.226     378.556
# 2016-12-31   1212.56800  315.063  34.580     349.643
# 2017-12-31   1107.11488  721.176  19.980     741.156

# %% [markdown]
# Note: Available frequencies in pandas include hourly (‘H’), calendar daily (‘D’), business daily (‘B’), weekly (‘W’), monthly (‘M’), quarterly (‘Q’), annual (‘A’), and many others.
#
# What we have done above is say “hey, the data was collected at a day’s interval and hence each row is a new day”. So technically, we should have values for power consumption, solar production, wind production, etc for all days from 2006–2017.
#
# In case, some days are missing in our data, the above code is going to insert empty rows and in each of these rows the values corresponding to the columns would be allNaNs. In order to avoid these NaN values, we can tell as.freq function how to fill these null values

# %%
data_freq = data.asfreq('D', method = 'ffill')
data_freq
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
data_freq = data.asfreq('m', method = 'ffill')
data_freq
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-31   1575.12900      NaN     NaN         NaN
# 2006-02-28   1507.49000      NaN     NaN         NaN
# 2006-03-31   1429.06600      NaN     NaN         NaN
# 2006-04-30   1026.35200      NaN     NaN         NaN
# 2006-05-31   1380.17500      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-08-31   1417.97368  208.497  70.794     279.291
# 2017-09-30   1216.86135  198.308  91.066     289.374
# 2017-10-31   1204.08577  256.960  56.767     313.727
# 2017-11-30   1617.03309   66.389  14.314      80.703
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [144 rows x 4 columns]

# %% [markdown]
# ffill refers to forward fill. This means when a null is encountered for a particular column, it will be replaced by the value in the previous row. As an example:

# %% [markdown]
# ## Resampling
# Resampling simply refers to an aggregation of data over a certain time period. Its performance is similar to the group by function in SQL, i.e. data is first split into time bins and some computation is performed on each bin. For instance, given our daily data, we can resample (or bin) it by the month or year and generate some relevant statistics such as minimum, maximum, or mean values.
#
# ### Weekly Resampling
# To compute weekly mean values for electricity consumption, wind, and solar production:

# %%
data_columns = ['Consumption', 'Wind', 'Solar', 'Wind+Solar']
data_weekly_mean = data[data_columns].resample('W').mean() # W stands for weekly
data_weekly_mean
# Out:
#             Consumption        Wind      Solar  Wind+Solar
# Date
# 2006-01-01  1069.184000         NaN        NaN         NaN
# 2006-01-08  1381.300143         NaN        NaN         NaN
# 2006-01-15  1486.730286         NaN        NaN         NaN
# 2006-01-22  1490.031143         NaN        NaN         NaN
# 2006-01-29  1514.176857         NaN        NaN         NaN
# ...                 ...         ...        ...         ...
# 2017-12-03  1536.236314  284.334286  18.320857  302.655143
# 2017-12-10  1554.824946  636.514714  16.440286  652.955000
# 2017-12-17  1543.856889  442.531857  18.143714  460.675571
# 2017-12-24  1440.342401  339.018429   9.895143  348.913571
# 2017-12-31  1203.265211  604.699143  19.240143  623.939286
#
# [627 rows x 4 columns]

# %%
data_columns = ['Consumption', 'Wind', 'Solar', 'Wind+Solar']
data_monthly_max = data[data_columns].resample('Y').max() # Y stands for weekly
data_monthly_max
# Out:
#             Consumption     Wind    Solar  Wind+Solar
# Date
# 2006-12-31     1613.312      NaN      NaN         NaN
# 2007-12-31     1644.873      NaN      NaN         NaN
# 2008-12-31     1606.299      NaN      NaN         NaN
# 2009-12-31     1538.894      NaN      NaN         NaN
# 2010-12-31     1709.568  447.685      NaN         NaN
# 2011-12-31     1607.306  493.380      NaN         NaN
# 2012-12-31     1615.078  523.851  189.252     528.922
# 2013-12-31     1563.832  556.412  204.441     576.595
# 2014-12-31     1659.960  648.537  212.446     663.359
# 2015-12-31     1651.314  696.637  218.299     731.845
# 2016-12-31     1672.320  751.656  229.714     783.936
# 2017-12-31     1682.002  826.278  241.580     851.556

# %% [markdown]
# If you notice the indices in the output, you would observe that they are at a gap of one week, we have Jan1 2006 followed by Jan8 2006, and so on. The first row above, labeled 2006–01–01, contains the mean of all the data contained in the time bin 2006–01–01 through 2006–01–07.

# %% [markdown]
# ###Monthly Resampling
# Similarly, to compute monthly maximum values for electricity consumption, wind, and solar production:

# %%
data_columns = ['Consumption', 'Wind', 'Solar', 'Wind+Solar']
data_monthly_max = data[data_columns].resample('M').max() # M stands for weekly
data_monthly_max
# Out:
#             Consumption     Wind    Solar  Wind+Solar
# Date
# 2006-01-31   1613.31200      NaN      NaN         NaN
# 2006-02-28   1606.66700      NaN      NaN         NaN
# 2006-03-31   1545.83400      NaN      NaN         NaN
# 2006-04-30   1447.79800      NaN      NaN         NaN
# 2006-05-31   1380.17500      NaN      NaN         NaN
# ...                 ...      ...      ...         ...
# 2017-08-31   1434.05200  455.379  216.117     601.010
# 2017-09-30   1460.61621  761.751  168.123     838.572
# 2017-10-31   1508.51484  819.818  123.715     846.617
# 2017-11-30   1617.03309  743.280   57.358     772.775
# 2017-12-31   1651.90418  812.422   42.994     822.371
#
# [144 rows x 4 columns]

# %% [markdown]
# ##Rolling windows
# This is quite similar to the resampling process that we just learned. The difference is that the bins over which some aggregating functions are performed) are overlapping.
#
# Bins in case of weekly resampling: Jan1- Jan 7; Jan8 - Jan14, Jan 15 - Jan 21, etc
#
# Bins in case of weekly rolling: Jan1- Jan7; Jan 2- Jan 8, Jan 3- Jan 9, etc.
#
# To compute a 7-day rolling mean:

# %%
data_columns = ['Consumption', 'Wind', 'Solar', 'Wind+Solar']
data_7d_rol = data[data_columns].rolling(window = 7, center = True).mean()
data_7d_rol
# Out:
#             Consumption        Wind      Solar  Wind+Solar
# Date
# 2006-01-01          NaN         NaN        NaN         NaN
# 2006-01-02          NaN         NaN        NaN         NaN
# 2006-01-03          NaN         NaN        NaN         NaN
# 2006-01-04  1361.471429         NaN        NaN         NaN
# 2006-01-05  1381.300143         NaN        NaN         NaN
# ...                 ...         ...        ...         ...
# 2017-12-27  1208.214129  617.734286  17.807143  635.541429
# 2017-12-28  1203.265211  604.699143  19.240143  623.939286
# 2017-12-29          NaN         NaN        NaN         NaN
# 2017-12-30          NaN         NaN        NaN         NaN
# 2017-12-31          NaN         NaN        NaN         NaN
#
# [4383 rows x 4 columns]

# %% [markdown]
# In the above command, center = True means for the time bin, say Jan 1 to Jan 8, the rolling mean would be calculated and placed next to the center of the bin i.e. Jan 4. To make it clearer, let's check the output of the above code:
#
# As you can see, the mean consumption value (of 1361.471) in 2006–01–04 was calculated by averaging the values from 2006–01–01 to 2006–01–07. Similarly, the mean consumption value (of 1381.300) in 2006–01–05 was calculated by averaging the values from 2006–01–02 to 2006–01–08.
#
# By the same logic, to calculate the mean consumption value for 2006–01–01, we would need to average the values from 2005–12–29 to 2006–01–04. However, the data for the year 2005 is missing and thus we obtain a Null for the first few rows.
#
#
# For more info: https://towardsdatascience.com/time-series-analysis-using-pandas-in-python-f726d87a97d8
