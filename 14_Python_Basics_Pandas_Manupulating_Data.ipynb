# %% [markdown]
# <a href="https://colab.research.google.com/github/sushily1997/python_Basics/blob/main/14_Python_Basics_Pandas_Manupulating_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Adding new column to existing DataFrame in Pandas
#
# Method #1: By declaring a new list as a column.

# %%
# Import pandas package
import pandas as pd

# Define a dictionary containing Students data
data = {'Name': ['Om', 'Ravi', 'Gaurav', 'Abhishek'],
		'Height': [5.3, 6, 5.4, 5.2],
		'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}

# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
print(df)
print("*********************************************")
# Declare a list that is to be converted into a column
cities = ['Delhi', 'Pune', 'Mumbai', 'Aurangabad']

# Using 'Address' as the column name
# and equating it to the list
df['Address'] = cities

# Observe the result
df
# Out:
#        Name  Height Qualification
# 0        Om     5.3           Msc
# 1      Ravi     6.0            MA
# 2    Gaurav     5.4           Msc
# 3  Abhishek     5.2           Msc
# *********************************************
#        Name  Height Qualification     Address
# 0        Om     5.3           Msc       Delhi
# 1      Ravi     6.0            MA        Pune
# 2    Gaurav     5.4           Msc      Mumbai
# 3  Abhishek     5.2           Msc  Aurangabad

# %% [markdown]
# Method #2: Using Dataframe.assign() method
#
# This method will create a new dataframe with a new column added to the old dataframe.

# %%
# Import pandas package
import pandas as pd

# Define a dictionary containing Students data
data = {'Name': ['Om', 'Ravi', 'Gaurav', 'Abhishek'],
		'Height': [5.3, 6, 5.4, 5.2],
		'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}


# Convert the dictionary into DataFrame
df = pd.DataFrame(data)

# Using 'Address' as the column name and equating it to the list
df2 = df.assign(address = ['Delhi', 'Pune', 'Mumbai', 'Aurangabad'])
# Observe the result
df2
# Out:
#        Name  Height Qualification     address
# 0        Om     5.3           Msc       Delhi
# 1      Ravi     6.0            MA        Pune
# 2    Gaurav     5.4           Msc      Mumbai
# 3  Abhishek     5.2           Msc  Aurangabad

# %% [markdown]
# # Delete rows/columns from DataFrame using Pandas.drop()
#
# Syntax:
# DataFrame.drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors=’raise’)
#
# Parameters:
#
# labels: String or list of strings referring row or column name.
#
# axis: int or string value, 0 ‘index’ for Rows and 1 ‘columns’ for Columns.
#
# index or columns: Single label or list. index or columns are an alternative to axis and cannot be used together.
#
# level: Used to specify level in case data frame is having multiple level index.
#
# inplace: Makes changes in original Data Frame if True.
#
# errors: Ignores error if any value from the list doesn’t exists and drops rest of the values when errors = ‘ignore’
#
# Return type: Dataframe with dropped values

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/employees.csv",index_col ="First Name")

# %%
data
# Out:
#             Gender  Start Date Last Login Time  Salary  Bonus %  \
# First Name
# Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# Thomas        Male   3/31/1996         6:53 AM   61933    4.170
# Maria       Female   4/23/1993        11:17 AM  130590   11.858
# Jerry         Male    3/4/2005         1:00 PM  138705    9.340
# Larry         Male   1/24/1998         4:47 PM  101004    1.389
# ...            ...         ...             ...     ...      ...
# Henry          NaN  11/23/2014         6:09 AM  132483   16.655
# Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# Russell       Male   5/20/2013        12:39 PM   96914    1.421
# Larry         Male   4/20/2013         4:45 PM   60500   11.985
# Albert        Male   5/15/2012         6:24 PM  129949   10.169
#
#            Senior Management                  Team
# First Name
# Douglas                 True             Marketing
# Thomas                  True                   NaN
# ...

# %%
# Example #1: Dropping Rows by index label
#In his code, A list of index labels is passed and the rows corresponding to those labels are dropped using .drop() method.

# importing pandas module
import pandas as pd

# dropping passed values
data.drop(["Thomas", "Larry", "Russell"],axis=0, inplace = True)

# display
data
# Out:
#             Gender  Start Date Last Login Time  Salary  Bonus %  \
# First Name
# Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# Maria       Female   4/23/1993        11:17 AM  130590   11.858
# Jerry         Male    3/4/2005         1:00 PM  138705    9.340
# Dennis        Male   4/18/1987         1:35 AM  115163   10.125
# Ruby        Female   8/17/1987         4:20 PM   65476   10.012
# ...            ...         ...             ...     ...      ...
# Tina        Female   5/15/1997         3:53 PM   56450   19.040
# George        Male   6/21/2013         5:47 PM   98874    4.479
# Henry          NaN  11/23/2014         6:09 AM  132483   16.655
# Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# Albert        Male   5/15/2012         6:24 PM  129949   10.169
#
#            Senior Management          Team
# First Name
# Douglas                 True     Marketing
# Maria                  False       Finance
# ...

# %% [markdown]
# Example #2 : Dropping columns with column name
#
# In his code, Passed columns are dropped using column names. axis parameter is kept 1 since 1 refers to columns.

# %%
# importing pandas module
import pandas as pd

# making data frame from csv file
data = pd.read_csv("/content/drive/MyDrive/employees.csv",index_col ="First Name")

# dropping passed columns
data.drop(["Gender", "Team"], axis = 1, inplace = True)

# display
data
# Out:
#             Start Date Last Login Time  Salary  Bonus % Senior Management
# First Name
# Douglas       8/6/1993        12:42 PM   97308    6.945              True
# Thomas       3/31/1996         6:53 AM   61933    4.170              True
# Maria        4/23/1993        11:17 AM  130590   11.858             False
# Jerry         3/4/2005         1:00 PM  138705    9.340              True
# Larry        1/24/1998         4:47 PM  101004    1.389              True
# ...                ...             ...     ...      ...               ...
# Henry       11/23/2014         6:09 AM  132483   16.655             False
# Phillip      1/31/1984         6:30 AM   42392   19.675             False
# Russell      5/20/2013        12:39 PM   96914    1.421             False
# Larry        4/20/2013         4:45 PM   60500   11.985             False
# Albert       5/15/2012         6:24 PM  129949   10.169              True
#
# [1000 rows x 5 columns]

# %% [markdown]
# # Pandas DataFrame.truncate
#
# Pandas DataFrame.truncate() function is used to truncate a Series or DataFrame before and after some index value. This is a useful shorthand for boolean indexing based on index values above or below certain thresholds.
#
# Example #1: Use DataFrame.truncate() function to truncate some entries before and after the passed labels of the given dataframe.

# %%
# importing pandas as pd
import pandas as pd

# Creating the DataFrame
df = pd.DataFrame({'Weight':[45, 88, 56, 15, 71],
                'Name':['Ram', 'Ankush', 'Anil', 'Rohit', 'Kartik'],
                'Age':[14, 25, 55, 8, 21]})

# Create the index
index_ = pd.date_range('2022-10-09 08:45', periods = 5, freq ='H')

# Set the index
df.index = index_

# Print the DataFrame
print(df)
# Out:
#                      Weight    Name  Age
# 2022-10-09 08:45:00      45     Ram   14
# 2022-10-09 09:45:00      88  Ankush   25
# 2022-10-09 10:45:00      56    Anil   55
# 2022-10-09 11:45:00      15   Rohit    8
# 2022-10-09 12:45:00      71  Kartik   21

# %% [markdown]
# Now we will use DataFrame.truncate() function to truncate the entries before ‘2010-10-09 09:45:00’ and after ‘2010-10-09 11:45:00’ in the given dataframe.

# %%
# return the truncated dataframe
result = df.truncate(before = '2022-10-09 09:45:00', after = '2022-10-09 11:45:00')

# Print the result
print(result)
# Out:
#                      Weight    Name  Age
# 2022-10-09 09:45:00      88  Ankush   25
# 2022-10-09 10:45:00      56    Anil   55
# 2022-10-09 11:45:00      15   Rohit    8

# %% [markdown]
# # Working with Missing Data in Pandas
#
# Missing Data can occur when no information is provided for one or more items or for a whole unit. Missing Data is a very big problem in a real-life scenarios. Missing Data can also refer to as NA(Not Available) values in pandas. In DataFrame sometimes many datasets simply arrive with missing data, either because it exists and was not collected or it never existed. For Example, Suppose different users being surveyed may choose not to share their income, some users may choose not to share the address in this way many datasets went missing.
#
#
# In Pandas missing data is represented by two value:
#
# **None:** None is a Python singleton object that is often used for missing data in Python code.
#
# **NaN :** NaN (an acronym for Not a Number), is a special floating-point value recognized by all systems that use the standard IEEE floating-point representation
#
# Pandas treat None and NaN as essentially interchangeable for indicating missing or null values. To facilitate this convention, there are several useful functions for detecting, removing, and replacing null values in Pandas DataFrame :
#
# isnull()
#
# notnull()
#
# dropna()
#
# fillna()
#
# replace()
#
# interpolate()

# %%
data = pd.read_csv("/content/drive/MyDrive/employees.csv")
data
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
#isnull()
null=pd.isnull(data['Team'])
data[null]
# Out:
#       First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 10        Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 23           NaN    Male   6/14/2012         4:19 PM  125792    5.042
# 32           NaN    Male   8/21/1998         2:27 PM  122340    6.417
# 91         James     NaN   1/26/2005        11:00 PM  128771    8.309
# 109  Christopher    Male   4/22/2000        10:15 AM   37919   11.449
# 139          NaN  Female   10/3/1990         1:08 AM  132373   10.527
# 199     Jonathan    Male   7/17/2009         8:15 AM  130581   16.736
# 258      Michael    Male   1/24/2002         3:04 AM   43586   12.659
# 290       Jeremy    Male   6/14/1988         6:20 PM  129460   13.657
# 314        Bobby    Male   3/31/1996         5:40 PM  112117    6.338
# 367       Edward    Male    8/4/1989         6:06 AM   66067   10.957
# ...

# %%
#notnull()

# creating bool series False for NaN values

Nnull = pd.notnull(data["Gender"])
 
# displayed data only with team = NaN
data[Nnull]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
#dropna()
# making new data frame with dropped NA values 

new_data = data.dropna(axis = 0, how ='any') 

  
# comparing sizes of data frames 

print("Old data frame length:", len(data), "\nNew data frame length:",  

       len(new_data), "\nNumber of rows with at least 1 NA value: ", 

       (len(data)-len(new_data)))
# Out:
# Old data frame length: 1000
# New data frame length: 764
# Number of rows with at least 1 NA value:  236

# %%
#fillna()
import numpy as np
import pandas as pd
df = pd.DataFrame([[np.nan, 2, np.nan, 0],
                   [3, 4, np.nan, 1],
                   [5, np.nan, np.nan, 6],
                   [np.nan, 4, np.nan, 5]],
                 columns=list('PQRS'))
df
# Out:
#      P    Q   R  S
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  5.0  NaN NaN  6
# 3  NaN  4.0 NaN  5

# %%
values = {'P': 0, 'Q': 1, 'R': 2, 'S': 3}
df.fillna(value=values)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
df.fillna(method='ffill')
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %%
df.fillna(value=values, limit=1)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
#replace()
info = pd.DataFrame({  
    'name':['Pratik','Sanjay','ganu'],  
    'age':[27,34,31],  
    'city':['pune','parbhani','Latur']  
})  
info.replace({  
    34:29,  
    'Sanjay':'vinu'  
})
# Out:
#      name  age      city
# 0  Pratik   27      pune
# 1    vinu   29  parbhani
# 2    ganu   31     Latur

# %%
#interpolate()
df = pd.DataFrame([(0.0, np.nan, -1.0, 1.0),(np.nan, 2.0, np.nan, np.nan),(2.0, 3.0, np.nan, 9.0),],columns=list('abcd'))
print(df)
print("-----Filling the null values using the polynomial method-----")
print(df['a'].interpolate(method='polynomial', limit_direction='forward',order=1))
# Out:
#      a    b    c    d
# 0  0.0  NaN -1.0  1.0
# 1  NaN  2.0  NaN  NaN
# 2  2.0  3.0  NaN  9.0
# -----Filling the null values using the polynomial method-----
# 0    0.0
# 1    1.0
# 2    2.0
# Name: a, dtype: float64

# %%
df = pd.DataFrame({'X': [1, 2, 3, None, 3],
                   'Y': [4, None, 8, None, 3]})
print("DataFrame:")
print(df)

filled_df = df.interpolate()

print("Interploated DataFrame:")
print(filled_df)
# Out:
# DataFrame:
#      X    Y
# 0  1.0  4.0
# 1  2.0  NaN
# 2  3.0  8.0
# 3  NaN  NaN
# 4  3.0  3.0
# Interploated DataFrame:
#      X    Y
# 0  1.0  4.0
# 1  2.0  6.0
# 2  3.0  8.0
# 3  3.0  5.5
# 4  3.0  3.0

# %% [markdown]
# ##Checking for missing values using isnull() and notnull()
# In order to check missing values in Pandas DataFrame, we use a function isnull() and notnull(). Both function help in checking whether a value is NaN or not. These function can also be used in Pandas Series in order to find null values in a series.
#
# ##Checking for missing values using isnull()
# In order to check null values in Pandas DataFrame, we use isnull() function this function return dataframe of Boolean values which are True for NaN values.

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
		'Second Score': [30, 45, 56, np.nan],
		'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe from list
df = pd.DataFrame(dict)
print(df)
print("******************************************")

# using isnull() function
df.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0
# ******************************************
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
df.isnull().sum() # find the sum of null values column wise
# Out:
# First Score     1
# Second Score    1
# Third Score     1
# dtype: int64

# %%
df.info() # info method to get non null count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   First Score   3 non-null      float64
#  1   Second Score  3 non-null      float64
#  2   Third Score   3 non-null      float64
# dtypes: float64(3)
# memory usage: 224.0 bytes

# %% [markdown]
# # Checking for missing values using notnull()
# In order to check null values in Pandas Dataframe, we use notnull() function this function return dataframe of Boolean values which are False for NaN values.

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
		'Second Score': [30, 45, 56, np.nan],
		'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe using dictionary
df = pd.DataFrame(dict)

# using notnull() function
df.notnull()
# Out:
#    First Score  Second Score  Third Score
# 0         True          True        False
# 1         True          True         True
# 2        False          True         True
# 3         True         False         True

# %% [markdown]
# # Filling missing values using fillna(), replace() and interpolate()
# In order to fill null values in a datasets, we use fillna(), replace() and interpolate() function these function replace NaN values with some value of their own. All these function help in filling a null values in datasets of a DataFrame. Interpolate() function is basically used to fill NA values in the dataframe but it uses various interpolation technique to fill the missing values rather than hard-coding the value.

# %%
"Code #1: Filling null values with a single value"
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100,47, 90, np.nan, 95],
		'Second Score': [30, 45,48, 56, np.nan],
		'Third Score':[np.nan, 40,67, 80, 98]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

# filling missing value using fillna()
df.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         47.0          45.0         40.0
# 2         90.0          48.0         67.0
# 3          0.0          56.0         80.0
# 4         95.0           0.0         98.0

# %%
"Code #2: Filling null values with the previous ones"
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
		'Second Score': [30, 45, 56, np.nan],
		'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

# filling a missing value with
# previous ones
df.fillna(method ='pad')
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %%
"Code #3: Filling null value with the next ones"
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
		'Second Score': [30, 45, 56, np.nan],
		'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

# filling null value using fillna() function
df.fillna(method ='bfill')
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0         40.0
# 1         90.0          45.0         40.0
# 2         95.0          56.0         80.0
# 3         95.0           NaN         98.0

# %% [markdown]
# ### Code #4: Filling null values in CSV File

# %%
# making data frame from csv file
data = pd.read_csv("/content/drive/MyDrive/employees.csv")

# Printing the first 10 to 24 rows of
# the data frame for visualization
data[10:25]
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 15    Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# 16     Jeremy    Male   9/21/2010         5:56 AM   90370    7.369
# 17      Shawn    Male   12/7/1986         7:45 PM  111737    6.414
# 18      Diana  Female  10/23/1981        10:27 AM  132940   19.082
# 19      Donna  Female   7/22/2010         3:48 AM   81014    1.894
# 20       Lois     NaN   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew    Male    9/5/1995         2:12 AM  100612   13.645
# 22     Joshua     NaN    3/8/2012         1:58 AM   90816   18.816
# ...

# %%
# Now we are going to fill all the null values in Gender column with “No Gender”

# filling a null values using fillna()
data["Gender"].fillna("No Gender", inplace = True)

data
# Out:
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...        ...         ...             ...     ...      ...
# 995      Henry  No Gender  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
"""Code #5: Filling a null values using replace() method"""
data = pd.read_csv("/content/drive/MyDrive/employees.csv")

data.replace(to_replace = np.nan, value = -00)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry       0  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                     0
# ...

# %%
"Code #6: Using interpolate() function to fill the missing values using linear method."
# importing pandas as pd
import pandas as pd
	
# Creating the dataframe
df = pd.DataFrame({"A":[12, 4, 5, None, 1],
				"B":[None, 2, 54, 3, None],
				"C":[20, 16, None, 3, 8],
				"D":[14, 3, None, None, 6]})
	
# Print the dataframe
df
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3   NaN   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0

# %%
# to interpolate the missing values
df.interpolate(method ='linear', limit_direction ='forward')

"""As we can see the output, values in the first row could not get filled as the direction of filling of values is forward 
and there is no previous value which could have been used in interpolation."""
# Out:
# 'As we can see the output, values in the first row could not get filled as the direction of filling of values is forward \nand there is no previous value which could have been used in interpolation.'

# %% [markdown]
# # Dropping missing values using dropna()
# In order to drop a null values from a dataframe, we used dropna() function this function drop Rows/Columns of datasets with Null values in different ways.
#
# Code #1: Dropping rows with at least 1 null value.

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
		'Second Score': [30, np.nan, 45, 56],
		'Third Score':[52, 40, 80, 98],
		'Fourth Score':[np.nan, np.nan, np.nan, 65]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)
	
df
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
df.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0

# %%
"Code #2: Dropping rows if all values in that row are missing."
df.dropna(how = 'all')
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
"Code #3: Dropping columns with at least 1 null value."
df.dropna(axis = 1)
# Out:
#    Third Score
# 0           52
# 1           40
# 2           80
# 3           98

# %% [markdown]
# ### Code #4: Dropping Rows with at least 1 null value in CSV file

# %%
data = pd.read_csv("/content/drive/MyDrive/employees.csv")
# making new data frame with dropped NA values 
new_data = data.dropna(axis = 0, how ='any') 
    
print(new_data.head())
"Now we compare sizes of data frames so that we can come to know how many rows had at least 1 Null value"
print("Old data frame length:", len(data))
print("New data frame length:", len(new_data)) 
print("Number of rows with at least 1 NA value: ", (len(data)-len(new_data)))
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male  4/18/1987         1:35 AM  115163   10.125
#
#   Senior Management             Team
# 0              True        Marketing
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal
# Old data frame length: 1000
# New data frame length: 764
# Number of rows with at least 1 NA value:  236
